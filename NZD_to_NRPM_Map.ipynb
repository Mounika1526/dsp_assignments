# %%
import folium
world_map=folium.Map()
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
 Narsipatnam=folium.Map(location=[17.6664,82.6105])
 Narsipatnam
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from branca.element import Figure
fig5=Figure(height=550,width=1500)
map5=folium.Map(location=[16.7107, 81.0952],tiles='cartodbpositron',zoom_start=14)
fig5.add_child(map5)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
coords1=[[16.78977017543865, 80.84455930518179],[16.76741812612896, 80.88438474231319],[16.731912413103167, 80.91047727008892],[16.697715473655176, 80.93794308880024],
         [16.68456117347936, 80.96952878031823],[16.716129971911638, 81.03132687241866],[16.7384880446406, 81.11647091042371],[16.763473373990095, 81.20161494842877],
         [16.834466378903407, 81.25105342210912],[16.883094379688195, 81.32521113262965],[16.935651103473745, 81.39662226127905],[16.980312781354897, 81.47077997179957],
         [17.031529264298012, 81.53395135483557],[17.04991125256369, 81.60673581028729],[17.026276938447992, 81.69462643016348],[17.052537102994897, 81.77839717723296],
         [17.052537102994897, 81.863541215238],[17.112921464975038, 81.92259272546731],[17.157540798833896, 81.99263056318114],[17.190342291412676, 82.07777460118619],
         [17.236254620619185, 82.15055902077114],[17.227073066825454, 82.23982293158289],[17.253412004725035, 82.36437975335834],[17.304922384593425, 82.43271005905423],
         [17.33067216786834, 82.48305870535648],[17.359850890391467, 82.52981101978],[17.40789983472404, 82.53340735165872],[17.4713737052369, 82.50104036475014],
         [17.491955080659924, 82.49204953956098],[17.543398313614794, 82.52441652646958],[17.613680450536698, 82.57116884089308],[17.6479544972669, 82.59993949592294],
         [17.67022913120532, 82.60893032561977]]
coords2=[[16.99990316382945, 81.80364744909922],[17.026823579483644, 81.80708067643812],[17.043236566647998, 81.83797972248834],[17.05899167845982, 81.86475889573187],
         [17.080652786500462, 81.89840452365321],[17.07999642623886, 81.93685666984904],[17.086559924878827, 81.97530881604487],[17.09049791313638, 82.00964108943401],
         [17.085903585413366, 82.05083981750097],[17.08459089954955, 82.09478512743904],[17.074745460982196, 82.1208776552148],[17.052427210021886, 82.13804379190937],
         [17.045206028283104, 82.16688290155622],[17.036671544657967, 82.1916021383964],[17.026823579483644, 82.21975460257549],[17.02944975422831, 82.21082821149432],
         [17.0248539242332, 82.2314275755278],[16.99464994868118, 82.2424139030123]]
coords3=[[16.993928835308054, 82.24677504900366],[17.054332144453706, 82.24265517619696],[17.193447929580707, 82.31131972297523],[17.264278127355073, 82.38410414256018],
         [17.308860969194896, 82.45963514401627],[17.26558954145012, 82.39371717910913],[17.306238748037824, 82.43354261624053],[17.32328251692487, 82.48160779898531],
         [17.373093693009345, 82.53516614547237]]

# %%
f1=folium.FeatureGroup("Vehicle1")
f2=folium.FeatureGroup("Vehicle2")
f3=folium.FeatureGroup("Vehicle3")

#Adding Markers
folium.Marker(location=[16.7850, 80.8488],popup='Nuzvid',tooltip='Click here to see more details').add_to(map5)
folium.Marker(location=[17.0005, 81.8040],popup='Rajhmundary',tooltip='Click here to see more details').add_to(map5)
folium.Marker(location=[16.9891, 82.2475],popup='kakinada',tooltip='Click here to see more details').add_to(map5)
folium.Marker(location=[17.3573, 82.5443],popup='Tuni',tooltip='Click here to see more details').add_to(map5)
folium.Marker(location=[17.6664, 82.6105],popup='Narsipatnam',tooltip='Click here to see more details').add_to(map5)

#Adding Special Markers
folium.Marker(location=[16.780292102383186, 81.2203471428946],popup='KFC Restaurent',tooltip='Click here to see more details',icon=folium.Icon(color='red',prefix="fa",icon='hotel')).add_to(map5)
folium.Marker(location=[16.818247168850213, 81.26310934921398],popup='GOVT Hospital Bhimadolu',tooltip='Click here to see more details',icon=folium.Icon(color='green',prefix="fa",icon='stethoscope')).add_to(map5)
folium.Marker(location=[17.2789, 82.4013],popup='Annavaram Temple',tooltip='Click here to see more details',icon=folium.Icon(color='red',prefix="fa",icon='bell')).add_to(map5)
folium.Marker(location=[17.66555855467801, 82.6336777428545],popup='HOME',tooltip='Click here to see more details',icon=folium.Icon(color='red',prefix="fa",icon='home')).add_to(map5)

line_1=folium.vector_layers.PolyLine(coords1,popup="<b>Nuzvid to Narsipatnam Road</b>",tooltip="<b>Nuzvid to Narsipatnam Road</b>",color="green",weight=10).add_to(f1)
line_2=folium.vector_layers.PolyLine(coords2,popup="<b>Rajhmundary to Kakinada Road</b>",tooltip="<b> Rajhmundary to Kakinada Road</b>",color="blue",weight=10).add_to(f2)
line_3=folium.vector_layers.PolyLine(coords3,popup="<b>Kakinada to Tuni Road</b>",tooltip="<b> Kakinada to Tuni Road</b>",color="red",weight=10).add_to(f3)

f1.add_to(map5)
f2.add_to(map5)
f3.add_to(map5)
folium.LayerControl().add_to(map5)
map5
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
